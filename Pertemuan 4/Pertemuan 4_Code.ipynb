# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### Start coding

# %% [markdown]
# #### Importing data to pandas

# %%
# Import pandas
import pandas as pd

# Load data
df = pd.read_csv("pokemon_data.csv")

# Output
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# txt Data
df_txt = pd.read_csv("pokemon_data.txt", delimiter="\t")

# Output
df_txt.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# Excel(xlsx) data
df_excel = pd.read_excel("pokemon_data.xlsx")

# Output
df_excel.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %% [markdown]
# #### Slicing

# %% [markdown]
# **Column/s**

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Choosing specific columns
df[["Name", "Legendary", "Generation"]].head(10)
# Out:
#                         Name  Legendary  Generation
# 0                  Bulbasaur      False           1
# 1                    Ivysaur      False           1
# 2                   Venusaur      False           1
# 3      VenusaurMega Venusaur      False           1
# 4                 Charmander      False           1
# 5                 Charmeleon      False           1
# 6                  Charizard      False           1
# 7  CharizardMega Charizard X      False           1
# 8  CharizardMega Charizard Y      False           1
# 9                   Squirtle      False           1

# %%
# Choosing specific columns
df.iloc[:, 1:5].head(10)
# Out:
#                         Name Type 1  Type 2  HP
# 0                  Bulbasaur  Grass  Poison  45
# 1                    Ivysaur  Grass  Poison  60
# 2                   Venusaur  Grass  Poison  80
# 3      VenusaurMega Venusaur  Grass  Poison  80
# 4                 Charmander   Fire     NaN  39
# 5                 Charmeleon   Fire     NaN  58
# 6                  Charizard   Fire  Flying  78
# 7  CharizardMega Charizard X   Fire  Dragon  78
# 8  CharizardMega Charizard Y   Fire  Flying  78
# 9                   Squirtle  Water     NaN  44

# %% [markdown]
# **Row**

# %% [markdown]
# iloc

# %%
df.iloc[[9, 10, 11], ] # iloc means integer location

# Cara nulis [row, column] --[[row1, row2, row3], column(s)]
# Out:
#     #       Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 9   7   Squirtle  Water    NaN  44      48       65       50       64     43
# 10  8  Wartortle  Water    NaN  59      63       80       65       80     58
# 11  9  Blastoise  Water    NaN  79      83      100       85      105     78
#
#     Generation  Legendary
# 9            1      False
# 10           1      False
# 11           1      False

# %%
df.iloc[7, [1, -2, -1]]
# Out:
# Name          CharizardMega Charizard X
# Generation                            1
# Legendary                         False
# Name: 7, dtype: object

# %%
# Define variable
seratus_lima_ratus = df.iloc[99:500, [1, -2, -1]]

# Output
seratus_lima_ratus
# Out:
#                     Name  Generation  Legendary
# 99                Gastly           1      False
# 100              Haunter           1      False
# 101               Gengar           1      False
# 102    GengarMega Gengar           1      False
# 103                 Onix           1      False
# ..                   ...         ...        ...
# 495             Munchlax           4      False
# 496                Riolu           4      False
# 497              Lucario           4      False
# 498  LucarioMega Lucario           4      False
# 499           Hippopotas           4      False
#
# [401 rows x 3 columns]

# %% [markdown]
# Latihan 1
# ---
#
# Buatlah sebuah dataframe baru yang berisikan 77 row, dengan semua columns kecuali sp. attack dan sp. def

# %%
# Define variable
jawaban_soal_pertama = df.iloc[100:178, df.columns != -4]

# Output
jawaban_soal_pertama
# Out:
#        #               Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 100   93            Haunter    Ghost  Poison  45      50       45      115
# 101   94             Gengar    Ghost  Poison  60      65       60      130
# 102   94  GengarMega Gengar    Ghost  Poison  60      65       80      170
# 103   95               Onix     Rock  Ground  35      45      160       30
# 104   96            Drowzee  Psychic     NaN  60      48       45       43
# ..   ...                ...      ...     ...  ..     ...      ...      ...
# 173  159           Croconaw    Water     NaN  65      80       80       59
# 174  160         Feraligatr    Water     NaN  85     105      100       79
# 175  161            Sentret   Normal     NaN  35      46       34       35
# 176  162             Furret   Normal     NaN  85      76       64       45
# 177  163           Hoothoot   Normal  Flying  60      30       30       36
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Define variable
jawaban_soal_pertama_drop = df.drop(["Sp. Atk", "Sp. Def"], axis = 1)

jawaban_soal_pertama_drop
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  Speed  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49     45
# 1      2                Ivysaur    Grass  Poison  60      62       63     60
# 2      3               Venusaur    Grass  Poison  80      82       83     80
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123     80
# 4      4             Charmander     Fire     NaN  39      52       43     65
# ..   ...                    ...      ...     ...  ..     ...      ...    ...
# 795  719                Diancie     Rock   Fairy  50     100      150     50
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60     70
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60     80
# 799  721              Volcanion     Fire   Water  80     110      120     70
#
#      Generation  Legendary
# ...

# %% [markdown]
# loc

# %%
df.loc[df['Name']== "Bulbasaur"]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
new = df.loc[df["Legendary"] == True]

# Output
new
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### Filtering data

# %%
# Filter based on one column
df.loc[df["Legendary"] == True]
# Out:
#        #                      Name    Type 1  ... Speed  Generation  Legendary
# 156  144                  Articuno       Ice  ...    85           1       True
# 157  145                    Zapdos  Electric  ...   100           1       True
# 158  146                   Moltres      Fire  ...    90           1       True
# 163  150       MewtwoMega Mewtwo X   Psychic  ...   130           1       True
# 269  249                     Lugia   Psychic  ...   110           2       True
# 270  250                     Ho-oh      Fire  ...    90           2       True
# 417  380                    Latias    Dragon  ...   110           3       True
# 418  380         LatiasMega Latias    Dragon  ...   110           3       True
# 419  381                    Latios    Dragon  ...   110           3       True
# 420  381         LatiosMega Latios    Dragon  ...   110           3       True
# 424  383     GroudonPrimal Groudon    Ground  ...    90           3       True
# ...

# %%
# Filter based on one column
df.loc[(df["Legendary"] == True) & (df["Attack"] > 120) & (df["HP"] < 60)]
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 428  386   DeoxysNormal Forme  Psychic    NaN  50     150       50      150
# 429  386   DeoxysAttack Forme  Psychic    NaN  50     180       20      180
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 428       50    150           3       True
# 429       20    150           3       True
# 796      110    110           6       True

# %%
df["Total kekuatan"] = df.iloc[:, 4:6].sum(axis=1)

# Output
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total kekuatan
# ...

# %% [markdown]
# Latihan 2
# --
# Buatlah sebuah dataframe baru berisi pokemon dengan total kekuatan > 200

# %%
df.loc[df["Total kekuatan"] > 200]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 19    15      BeedrillMega Beedrill       Bug  Poison   65     150       40
# 45    40                 Wigglytuff    Normal   Fairy  140      70       45
# 74    68                    Machamp  Fighting     NaN   90     130       80
# 96    89                        Muk    Poison     NaN  105     105       75
# ..   ...                        ...       ...     ...  ...     ...      ...
# 792  716                    Xerneas     Fairy     NaN  126     131       95
# 793  717                    Yveltal      Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme    Dragon  Ground  108     100      121
# 796  719        DiancieMega Diancie      Rock   Fairy   50     160      110
# 798  720         HoopaHoopa Unbound   Psychic    Dark   80     160       60
#
# ...

# %%
df["Count"] = 1

df.groupby(["HP"]).count()["Count"]
# Out:
# HP
# 1      1
# 10     1
# 20     6
# 25     2
# 28     1
#       ..
# 165    1
# 170    1
# 190    1
# 250    1
# 255    1
# Name: Count, Length: 94, dtype: int64

# %% [markdown]
# #### Na handling

# %%
df.isna().any()
# Out:
# #                 False
# Name              False
# Type 1            False
# Type 2             True
# HP                False
# Attack            False
# Defense           False
# Sp. Atk           False
# Sp. Def           False
# Speed             False
# Generation        False
# Legendary         False
# Total kekuatan    False
# Count             False
# dtype: bool

# %%
df.fillna("Unspecified", inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1       Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass       Poison  45      49       49
# 1      2                Ivysaur    Grass       Poison  60      62       63
# 2      3               Venusaur    Grass       Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass       Poison  80     100      123
# 4      4             Charmander     Fire  Unspecified  39      52       43
# ..   ...                    ...      ...          ...  ..     ...      ...
# 795  719                Diancie     Rock        Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock        Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic        Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic         Dark  80     160       60
# 799  721              Volcanion     Fire        Water  80     110      120
#
# ...

# %% [markdown]
# #### Stats in pandas

# %%
df.cov()

# %%
#Correlation
correlation = df.corr()
correlation

# %%
df["HP"].rank(ascending=True)

# %%
#Mean
df["HP"].mean()

# %%
# Median
df[["HP", "Attack"]].median()

# %%
df["HP"].rank()

# %%
df.std()

# %%
df.cumsum()

# %%
df.prod()

# %% [markdown]
# #### Exporting data from pandas

# %%
new.to_csv("updated.csv")
new.to_excel("updated.xlsx")
new.to_csv("updated.txt")
